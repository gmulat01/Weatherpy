# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Import the requests library.
import requests

#import API key
from config import weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 608

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1acf8adbb09489515a242c0e8cd8ce93

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1acf8adbb09489515a242c0e8cd8ce93&q=Boston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 82.6,
#   'feels_like': 82.51,
#   'temp_min': 78.58,
#   'temp_max': 85.28,
#   'pressure': 1005,
#   'humidity': 44},
#  'visibility': 10000,
#  'wind': {'speed': 16.11, 'deg': 290, 'gust': 28.77},
#  'clouds': {'all': 40},
#  'dt': 1661976707,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1661940511,
#   'sunset': 1661988063},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 82.6,
#   'feels_like': 82.51,
#   'temp_min': 78.58,
#   'temp_max': 85.28,
#   'pressure': 1005,
#   'humidity': 44},
#  'visibility': 10000,
#  'wind': {'speed': 16.11, 'deg': 290, 'gust': 28.77},
#  'clouds': {'all': 40},
#  'dt': 1661976707,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1661940511,
#   'sunset': 1661988063},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 85.28 44 40 16.11

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2022, 8, 31, 20, 11, 47)

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Create an empty list to hold the weather data.
city_data = []

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | mokshan
# Processing Record 6 of Set 1 | porosozero
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | batagay-alyta
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | clinton
# Processing Record 11 of Set 1 | hofn
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | paracuru
# Processing Record 14 of Set 1 | sadiqabad
# Processing Record 15 of Set 1 | alice springs
# Processing Record 16 of Set 1 | georgiyevka
# Processing Record 17 of Set 1 | hasaki
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | hualmay
# Processing Record 21 of Set 1 | banda aceh
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | hamilton
# Processing Record 25 of Set 1 | omsukchan
# Processing Record 26 of Set 1 | lata
# Processing Record 27 of Set 1 | nuristan
# Processing Record 28 of Set 1 | bahia blanca
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | provideniya
# Processing Record 31 of Set 1 | aranos
# Processing Record 32 of Set 1 | katherine
# Processing Record 33 of Set 1 | atar
# Processing Record 34 of Set 1 | kapustin yar
# Processing Record 35 of Set 1 | brae
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | huarmey
# Processing Record 38 of Set 1 | talnakh
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | novobiryusinskiy
# Processing Record 41 of Set 1 | hambantota
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | katangli
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | galesong
# Processing Record 49 of Set 1 | san rafael
# Processing Record 50 of Set 1 | khatanga
# Processing Record 1 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 2 | lorengau
# Processing Record 3 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 2 | tuatapere
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | katsuura
# Processing Record 7 of Set 2 | huaral
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | moron
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | barra do garcas
# Processing Record 12 of Set 2 | marienburg
# Processing Record 13 of Set 2 | malumfashi
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | broome
# Processing Record 16 of Set 2 | carnarvon
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | tokoname
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | katobu
# Processing Record 22 of Set 2 | saskylakh
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | nome
# Processing Record 26 of Set 2 | georgetown
# Processing Record 27 of Set 2 | udachnyy
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | merauke
# Processing Record 30 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 2 | mnogovershinnyy
# Processing Record 33 of Set 2 | asyut
# Processing Record 34 of Set 2 | esperance
# Processing Record 35 of Set 2 | ratnagiri
# Processing Record 36 of Set 2 | namuac
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 2 | portland
# Processing Record 41 of Set 2 | inhambane
# Processing Record 42 of Set 2 | zharkent
# Processing Record 43 of Set 2 | chokurdakh
# Processing Record 44 of Set 2 | tokur
# Processing Record 45 of Set 2 | cabo san lucas
# Processing Record 46 of Set 2 | preeceville
# Processing Record 47 of Set 2 | deputatskiy
# Processing Record 48 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 2 | altamira
# Processing Record 50 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 3 | balud
# Processing Record 2 of Set 3 | ust-maya
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | sabratah
# Processing Record 5 of Set 3 | flinders
# Processing Record 6 of Set 3 | sao filipe
# Processing Record 7 of Set 3 | souillac
# Processing Record 8 of Set 3 | belsand
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | linhares
# Processing Record 11 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 3 | mount gambier
# Processing Record 13 of Set 3 | elizabeth city
# Processing Record 14 of Set 3 | bethel
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | ahipara
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | san cristobal
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 3 | maple creek
# Processing Record 22 of Set 3 | saleilua
# City not found. Skipping...
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | chernyshevskiy
# Processing Record 25 of Set 3 | sretensk
# Processing Record 26 of Set 3 | ndele
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | union
# Processing Record 29 of Set 3 | pahrump
# Processing Record 30 of Set 3 | alamogordo
# Processing Record 31 of Set 3 | norman wells
# Processing Record 32 of Set 3 | russkaya polyana
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | tabuk
# Processing Record 35 of Set 3 | wuwei
# Processing Record 36 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 3 | port-gentil
# Processing Record 38 of Set 3 | fort-shevchenko
# Processing Record 39 of Set 3 | praia da vitoria
# Processing Record 40 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 41 of Set 3 | delmas
# Processing Record 42 of Set 3 | bodh gaya
# Processing Record 43 of Set 3 | kalmunai
# Processing Record 44 of Set 3 | kirov
# Processing Record 45 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 46 of Set 3 | namwala
# Processing Record 47 of Set 3 | carutapera
# Processing Record 48 of Set 3 | port elizabeth
# Processing Record 49 of Set 3 | saint-francois
# Processing Record 50 of Set 3 | lardos
# Processing Record 1 of Set 4 | pisco
# Processing Record 2 of Set 4 | vestmannaeyjar
# Processing Record 3 of Set 4 | narsaq
# Processing Record 4 of Set 4 | ilulissat
# Processing Record 5 of Set 4 | langfang
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | vao
# Processing Record 8 of Set 4 | tugulym
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | east london
# Processing Record 11 of Set 4 | mindelo
# Processing Record 12 of Set 4 | calarasi
# Processing Record 13 of Set 4 | salalah
# Processing Record 14 of Set 4 | kodiak
# Processing Record 15 of Set 4 | matara
# Processing Record 16 of Set 4 | mancora
# Processing Record 17 of Set 4 | nurota
# Processing Record 18 of Set 4 | zhanaozen
# Processing Record 19 of Set 4 | yarmouth
# Processing Record 20 of Set 4 | tingi
# Processing Record 21 of Set 4 | ligayan
# Processing Record 22 of Set 4 | pangnirtung
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | dzhubga
# Processing Record 25 of Set 4 | yellowknife
# Processing Record 26 of Set 4 | kavieng
# Processing Record 27 of Set 4 | magadan
# Processing Record 28 of Set 4 | shirokiy
# Processing Record 29 of Set 4 | harper
# Processing Record 30 of Set 4 | sucua
# Processing Record 31 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 4 | brigantine
# Processing Record 33 of Set 4 | touros
# Processing Record 34 of Set 4 | namibe
# Processing Record 35 of Set 4 | leningradskiy
# Processing Record 36 of Set 4 | iqaluit
# Processing Record 37 of Set 4 | shingu
# Processing Record 38 of Set 4 | tuktoyaktuk
# Processing Record 39 of Set 4 | rossland
# Processing Record 40 of Set 4 | gamba
# Processing Record 41 of Set 4 | nanortalik
# Processing Record 42 of Set 4 | makakilo city
# Processing Record 43 of Set 4 | mareeba
# Processing Record 44 of Set 4 | henties bay
# Processing Record 45 of Set 4 | cidreira
# Processing Record 46 of Set 4 | bafoulabe
# Processing Record 47 of Set 4 | isangel
# Processing Record 48 of Set 4 | beidao
# Processing Record 49 of Set 4 | neijiang
# Processing Record 50 of Set 4 | cherskiy
# Processing Record 1 of Set 5 | seydisehir
# Processing Record 2 of Set 5 | port lincoln
# Processing Record 3 of Set 5 | guarapari
# Processing Record 4 of Set 5 | clyde river
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | kampot
# Processing Record 7 of Set 5 | sao joao da barra
# Processing Record 8 of Set 5 | ouesso
# Processing Record 9 of Set 5 | mar del plata
# Processing Record 10 of Set 5 | itaituba
# Processing Record 11 of Set 5 | ribeira grande
# Processing Record 12 of Set 5 | tutoia
# Processing Record 13 of Set 5 | delijan
# Processing Record 14 of Set 5 | launceston
# Processing Record 15 of Set 5 | vardo
# Processing Record 16 of Set 5 | neustadt
# Processing Record 17 of Set 5 | marsa matruh
# Processing Record 18 of Set 5 | pangkalanbuun
# Processing Record 19 of Set 5 | murchison
# Processing Record 20 of Set 5 | shetpe
# Processing Record 21 of Set 5 | usinsk
# Processing Record 22 of Set 5 | araouane
# Processing Record 23 of Set 5 | jalu
# Processing Record 24 of Set 5 | fortuna
# Processing Record 25 of Set 5 | jishou
# Processing Record 26 of Set 5 | san patricio
# Processing Record 27 of Set 5 | aripuana
# Processing Record 28 of Set 5 | bubaque
# Processing Record 29 of Set 5 | campoverde
# Processing Record 30 of Set 5 | zvishavane
# Processing Record 31 of Set 5 | dakar
# Processing Record 32 of Set 5 | kavaratti
# Processing Record 33 of Set 5 | chapais
# Processing Record 34 of Set 5 | pussi
# Processing Record 35 of Set 5 | bud
# Processing Record 36 of Set 5 | faanui
# Processing Record 37 of Set 5 | batsfjord
# Processing Record 38 of Set 5 | kaeo
# Processing Record 39 of Set 5 | ballina
# Processing Record 40 of Set 5 | parit raja
# Processing Record 41 of Set 5 | sari
# Processing Record 42 of Set 5 | poum
# Processing Record 43 of Set 5 | constitucion
# Processing Record 44 of Set 5 | arman
# Processing Record 45 of Set 5 | mayo
# Processing Record 46 of Set 5 | kaitangata
# Processing Record 47 of Set 5 | alekseyevsk
# Processing Record 48 of Set 5 | wah
# Processing Record 49 of Set 5 | kulhudhuffushi
# Processing Record 50 of Set 5 | ilembula
# Processing Record 1 of Set 6 | nishihara
# Processing Record 2 of Set 6 | lexington park
# Processing Record 3 of Set 6 | halifax
# Processing Record 4 of Set 6 | vendryne
# Processing Record 5 of Set 6 | rotterdam
# Processing Record 6 of Set 6 | geraldton
# Processing Record 7 of Set 6 | bafq
# Processing Record 8 of Set 6 | funadhoo
# Processing Record 9 of Set 6 | mattru
# Processing Record 10 of Set 6 | palu
# Processing Record 11 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 6 | ciudad bolivar
# Processing Record 13 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 14 of Set 6 | aban
# Processing Record 15 of Set 6 | fort smith
# Processing Record 16 of Set 6 | bengkulu
# Processing Record 17 of Set 6 | kozhva
# Processing Record 18 of Set 6 | te anau
# Processing Record 19 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 6 | ixtapa
# Processing Record 21 of Set 6 | arraial do cabo
# Processing Record 22 of Set 6 | lewisburg
# Processing Record 23 of Set 6 | pevek
# Processing Record 24 of Set 6 | panjwin
# City not found. Skipping...
# Processing Record 25 of Set 6 | luanda
# Processing Record 26 of Set 6 | vila franca do campo
# Processing Record 27 of Set 6 | longyearbyen
# Processing Record 28 of Set 6 | virginia beach
# Processing Record 29 of Set 6 | visby
# Processing Record 30 of Set 6 | chifeng
# Processing Record 31 of Set 6 | fort nelson
# Processing Record 32 of Set 6 | san luis
# Processing Record 33 of Set 6 | kyra
# Processing Record 34 of Set 6 | vostok
# Processing Record 35 of Set 6 | brownfield
# Processing Record 36 of Set 6 | honiara
# Processing Record 37 of Set 6 | walvis bay
# Processing Record 38 of Set 6 | waingapu
# Processing Record 39 of Set 6 | devonport
# Processing Record 40 of Set 6 | parvatsar
# Processing Record 41 of Set 6 | pundaguitan
# Processing Record 42 of Set 6 | anloga
# Processing Record 43 of Set 6 | bocaiuva
# Processing Record 44 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 6 | ibra
# Processing Record 46 of Set 6 | tambilil
# Processing Record 47 of Set 6 | solnechnyy
# Processing Record 48 of Set 6 | coaraci
# Processing Record 49 of Set 6 | severobaykalsk
# Processing Record 50 of Set 6 | tiksi
# Processing Record 1 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 7 | olinda
# Processing Record 3 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 7 | mancio lima
# Processing Record 5 of Set 7 | caravelas
# Processing Record 6 of Set 7 | tucuman
# Processing Record 7 of Set 7 | hobyo
# Processing Record 8 of Set 7 | zaozerne
# Processing Record 9 of Set 7 | kahului
# Processing Record 10 of Set 7 | janauba
# Processing Record 11 of Set 7 | manyana
# Processing Record 12 of Set 7 | dikson
# Processing Record 13 of Set 7 | saldanha
# Processing Record 14 of Set 7 | samarai
# Processing Record 15 of Set 7 | mabaruma
# Processing Record 16 of Set 7 | itzehoe
# Processing Record 17 of Set 7 | qeshm
# Processing Record 18 of Set 7 | acarau
# Processing Record 19 of Set 7 | tera
# Processing Record 20 of Set 7 | karratha
# Processing Record 21 of Set 7 | zdounky
# Processing Record 22 of Set 7 | ostrovnoy
# Processing Record 23 of Set 7 | airai
# Processing Record 24 of Set 7 | aksarka
# Processing Record 25 of Set 7 | davila
# Processing Record 26 of Set 7 | adrar
# Processing Record 27 of Set 7 | port hawkesbury
# Processing Record 28 of Set 7 | sibolga
# Processing Record 29 of Set 7 | novoagansk
# Processing Record 30 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 7 | namatanai
# Processing Record 32 of Set 7 | mlonggo
# Processing Record 33 of Set 7 | medenychi
# Processing Record 34 of Set 7 | yerbogachen
# Processing Record 35 of Set 7 | prado
# Processing Record 36 of Set 7 | kathmandu
# Processing Record 37 of Set 7 | bonavista
# Processing Record 38 of Set 7 | prince rupert
# Processing Record 39 of Set 7 | russkoye
# Processing Record 40 of Set 7 | carlisle
# Processing Record 41 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 7 | zabrani
# Processing Record 43 of Set 7 | dubbo
# Processing Record 44 of Set 7 | mayumba
# Processing Record 45 of Set 7 | japura
# Processing Record 46 of Set 7 | cachoeiras de macacu
# Processing Record 47 of Set 7 | lillooet
# Processing Record 48 of Set 7 | westport
# Processing Record 49 of Set 7 | bo phloi
# Processing Record 50 of Set 7 | burnie
# Processing Record 1 of Set 8 | zitacuaro
# Processing Record 2 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 8 | hami
# Processing Record 4 of Set 8 | abu dhabi
# Processing Record 5 of Set 8 | tongchuan
# Processing Record 6 of Set 8 | noisy-le-sec
# Processing Record 7 of Set 8 | ostersund
# Processing Record 8 of Set 8 | ambilobe
# Processing Record 9 of Set 8 | mount isa
# Processing Record 10 of Set 8 | bambanglipuro
# Processing Record 11 of Set 8 | aykhal
# Processing Record 12 of Set 8 | wewak
# Processing Record 13 of Set 8 | levelland
# Processing Record 14 of Set 8 | krasnyy tekstilshchik
# City not found. Skipping...
# Processing Record 15 of Set 8 | krotovka
# Processing Record 16 of Set 8 | sao sebastiao
# Processing Record 17 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 8 | bulungu
# Processing Record 19 of Set 8 | inuvik
# Processing Record 20 of Set 8 | karwar
# Processing Record 21 of Set 8 | agaro
# Processing Record 22 of Set 8 | pinotepa nacional
# Processing Record 23 of Set 8 | phuket
# Processing Record 24 of Set 8 | ormara
# Processing Record 25 of Set 8 | sungairaya
# Processing Record 26 of Set 8 | sorland
# Processing Record 27 of Set 8 | san quintin
# Processing Record 28 of Set 8 | murgab
# Processing Record 29 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 8 | aldan
# Processing Record 31 of Set 8 | kayes
# Processing Record 32 of Set 8 | tortoli
# Processing Record 33 of Set 8 | turukhansk
# Processing Record 34 of Set 8 | chumikan
# Processing Record 35 of Set 8 | nelson bay
# Processing Record 36 of Set 8 | guerrero negro
# Processing Record 37 of Set 8 | ugoofaaru
# Processing Record 38 of Set 8 | lehututu
# Processing Record 39 of Set 8 | laramie
# Processing Record 40 of Set 8 | dzhebariki-khaya
# Processing Record 41 of Set 8 | lasa
# Processing Record 42 of Set 8 | camocim
# Processing Record 43 of Set 8 | grindavik
# Processing Record 44 of Set 8 | cauquenes
# Processing Record 45 of Set 8 | the pas
# Processing Record 46 of Set 8 | pudozh
# Processing Record 47 of Set 8 | iquique
# Processing Record 48 of Set 8 | garissa
# Processing Record 49 of Set 8 | rocha
# Processing Record 50 of Set 8 | cam ranh
# Processing Record 1 of Set 9 | gaziantep
# Processing Record 2 of Set 9 | bahia honda
# Processing Record 3 of Set 9 | kutum
# Processing Record 4 of Set 9 | newport
# Processing Record 5 of Set 9 | barry
# Processing Record 6 of Set 9 | afyonkarahisar
# Processing Record 7 of Set 9 | vila velha
# Processing Record 8 of Set 9 | rabo de peixe
# Processing Record 9 of Set 9 | kuching
# Processing Record 10 of Set 9 | kawalu
# Processing Record 11 of Set 9 | acajutla
# Processing Record 12 of Set 9 | balaipungut
# Processing Record 13 of Set 9 | zelenoborskiy
# Processing Record 14 of Set 9 | whitehorse
# Processing Record 15 of Set 9 | buala
# Processing Record 16 of Set 9 | san carlos
# Processing Record 17 of Set 9 | alta floresta
# Processing Record 18 of Set 9 | berlevag
# Processing Record 19 of Set 9 | ipojuca
# Processing Record 20 of Set 9 | alofi
# Processing Record 21 of Set 9 | gladstone
# Processing Record 22 of Set 9 | amazar
# Processing Record 23 of Set 9 | lyantonde
# Processing Record 24 of Set 9 | college
# Processing Record 25 of Set 9 | koumac
# Processing Record 26 of Set 9 | achalpur
# Processing Record 27 of Set 9 | aklavik
# Processing Record 28 of Set 9 | egvekinot
# Processing Record 29 of Set 9 | bathsheba
# Processing Record 30 of Set 9 | aasiaat
# Processing Record 31 of Set 9 | manacapuru
# Processing Record 32 of Set 9 | abalak
# Processing Record 33 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 9 | ginda
# Processing Record 35 of Set 9 | cabra
# Processing Record 36 of Set 9 | muzhi
# Processing Record 37 of Set 9 | kirovskiy
# Processing Record 38 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 39 of Set 9 | abyek
# Processing Record 40 of Set 9 | bereda
# Processing Record 41 of Set 9 | road town
# Processing Record 42 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 43 of Set 9 | humberto de campos
# Processing Record 44 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 45 of Set 9 | iberia
# Processing Record 46 of Set 9 | sola
# Processing Record 47 of Set 9 | klaksvik
# Processing Record 48 of Set 9 | saint-pierre
# Processing Record 49 of Set 9 | simpang
# Processing Record 50 of Set 9 | mandali
# Processing Record 1 of Set 10 | avera
# Processing Record 2 of Set 10 | coahuayana
# Processing Record 3 of Set 10 | camargo
# Processing Record 4 of Set 10 | ephrata
# Processing Record 5 of Set 10 | beisfjord
# Processing Record 6 of Set 10 | francisco sa
# Processing Record 7 of Set 10 | broken hill
# Processing Record 8 of Set 10 | teya
# Processing Record 9 of Set 10 | kachug
# Processing Record 10 of Set 10 | morro bay
# Processing Record 11 of Set 10 | bulancak
# Processing Record 12 of Set 10 | shonguy
# Processing Record 13 of Set 10 | skibbereen
# Processing Record 14 of Set 10 | yar-sale
# Processing Record 15 of Set 10 | megion
# Processing Record 16 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 17 of Set 10 | santa rosa
# Processing Record 18 of Set 10 | lavrentiya
# Processing Record 19 of Set 10 | izhma
# Processing Record 20 of Set 10 | veraval
# Processing Record 21 of Set 10 | boo
# Processing Record 22 of Set 10 | bilibino
# Processing Record 23 of Set 10 | chishtian mandi
# Processing Record 24 of Set 10 | saint-joseph
# Processing Record 25 of Set 10 | atambua
# Processing Record 26 of Set 10 | la plata
# Processing Record 27 of Set 10 | yulara
# Processing Record 28 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 10 | paris
# Processing Record 30 of Set 10 | tautira
# Processing Record 31 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 32 of Set 10 | zarinsk
# Processing Record 33 of Set 10 | brigham city
# Processing Record 34 of Set 10 | panaba
# Processing Record 35 of Set 10 | sunamganj
# City not found. Skipping...
# Processing Record 36 of Set 10 | lagoa
# Processing Record 37 of Set 10 | vanderhoof
# Processing Record 38 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 39 of Set 10 | havre-saint-pierre
# Processing Record 40 of Set 10 | somerset east
# Processing Record 41 of Set 10 | shu
# Processing Record 42 of Set 10 | chuy
# Processing Record 43 of Set 10 | ondangwa
# Processing Record 44 of Set 10 | tabou
# Processing Record 45 of Set 10 | cockburn town
# Processing Record 46 of Set 10 | sitka
# Processing Record 47 of Set 10 | angra
# City not found. Skipping...
# Processing Record 48 of Set 10 | fukue
# Processing Record 49 of Set 10 | chengam
# Processing Record 50 of Set 10 | laguna
# Processing Record 1 of Set 11 | shenjiamen
# Processing Record 2 of Set 11 | khandyga
# Processing Record 3 of Set 11 | chulman
# Processing Record 4 of Set 11 | sehithwa
# Processing Record 5 of Set 11 | naron
# Processing Record 6 of Set 11 | kruisfontein
# Processing Record 7 of Set 11 | quelimane
# Processing Record 8 of Set 11 | lagos
# Processing Record 9 of Set 11 | hit
# Processing Record 10 of Set 11 | kaniama
# Processing Record 11 of Set 11 | muisne
# Processing Record 12 of Set 11 | manica
# Processing Record 13 of Set 11 | hearst
# Processing Record 14 of Set 11 | iracoubo
# Processing Record 15 of Set 11 | ewa beach
# Processing Record 16 of Set 11 | auki
# Processing Record 17 of Set 11 | penzance
# Processing Record 18 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 19 of Set 11 | vysha
# Processing Record 20 of Set 11 | acapulco
# Processing Record 21 of Set 11 | guilin
# Processing Record 22 of Set 11 | padang
# Processing Record 23 of Set 11 | vanavara
# Processing Record 24 of Set 11 | west odessa
# Processing Record 25 of Set 11 | vallenar
# Processing Record 26 of Set 11 | spassk-ryazanskiy
# Processing Record 27 of Set 11 | ionia
# Processing Record 28 of Set 11 | muros
# Processing Record 29 of Set 11 | biak
# Processing Record 30 of Set 11 | maragogi
# Processing Record 31 of Set 11 | yamasaki
# Processing Record 32 of Set 11 | epe
# Processing Record 33 of Set 11 | high prairie
# Processing Record 34 of Set 11 | rodrigues alves
# Processing Record 35 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 11 | marondera
# Processing Record 37 of Set 11 | shahreza
# Processing Record 38 of Set 11 | resistencia
# Processing Record 39 of Set 11 | kuytun
# Processing Record 40 of Set 11 | umm lajj
# Processing Record 41 of Set 11 | le port
# Processing Record 42 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 11 | saint-georges
# Processing Record 44 of Set 11 | escanaba
# Processing Record 45 of Set 11 | shunyi
# Processing Record 46 of Set 11 | khani
# Processing Record 47 of Set 11 | kanye
# Processing Record 48 of Set 11 | morant bay
# Processing Record 49 of Set 11 | goderich
# Processing Record 50 of Set 11 | manuk mangkaw
# Processing Record 1 of Set 12 | raton
# Processing Record 2 of Set 12 | aipe
# Processing Record 3 of Set 12 | montepuez
# Processing Record 4 of Set 12 | avon lake
# Processing Record 5 of Set 12 | saraza
# Processing Record 6 of Set 12 | presidencia roque saenz pena
# Processing Record 7 of Set 12 | puerto madryn
# Processing Record 8 of Set 12 | papetoai
# Processing Record 9 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 12 | kainantu
# Processing Record 11 of Set 12 | fort portal
# Processing Record 12 of Set 12 | kondinskoye
# Processing Record 13 of Set 12 | joshimath
# Processing Record 14 of Set 12 | svetlaya
# Processing Record 15 of Set 12 | drayton valley
# Processing Record 16 of Set 12 | nantucket
# Processing Record 17 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 12 | viransehir
# Processing Record 19 of Set 12 | maua
# Processing Record 20 of Set 12 | binabalian
# Processing Record 21 of Set 12 | casper
# Processing Record 22 of Set 12 | millville
# Processing Record 23 of Set 12 | quibdo
# Processing Record 24 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 12 | forssa
# Processing Record 26 of Set 12 | beyneu
# Processing Record 27 of Set 12 | de-kastri
# Processing Record 28 of Set 12 | fagersta
# Processing Record 29 of Set 12 | salamiyah
# Processing Record 30 of Set 12 | bhind
# Processing Record 31 of Set 12 | neuquen
# Processing Record 32 of Set 12 | rio claro
# Processing Record 33 of Set 12 | kitimat
# Processing Record 34 of Set 12 | hirara
# Processing Record 35 of Set 12 | gorkovskiy
# Processing Record 36 of Set 12 | kisumu
# Processing Record 37 of Set 12 | ipixuna
# Processing Record 38 of Set 12 | ryotsu
# Processing Record 39 of Set 12 | kizukuri
# Processing Record 40 of Set 12 | karachi
# Processing Record 41 of Set 12 | la tuque
# Processing Record 42 of Set 12 | port hardy
# Processing Record 43 of Set 12 | plouzane
# Processing Record 44 of Set 12 | ocumare del tuy
# Processing Record 45 of Set 12 | tondano
# Processing Record 46 of Set 12 | charlestown
# Processing Record 47 of Set 12 | medzilaborce
# Processing Record 48 of Set 12 | khandbari
# Processing Record 49 of Set 12 | sao domingos
# Processing Record 50 of Set 12 | formosa do rio preto
# Processing Record 1 of Set 13 | sechura
# Processing Record 2 of Set 13 | tornio
# Processing Record 3 of Set 13 | bonthe
# Processing Record 4 of Set 13 | cerro largo
# Processing Record 5 of Set 13 | abnub
# Processing Record 6 of Set 13 | marabba
# Processing Record 7 of Set 13 | plettenberg bay
# Processing Record 8 of Set 13 | cayenne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 561

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Vaini -21.2000 -175.2000     73.56        78          20
# 1             Atuona  -9.8000 -139.0333     76.96        71          10
# 2            Mataura -46.1927  168.8643     44.82        92          57
# 3             Albany  42.6001  -73.9662     78.94        51          19
# 4            Mokshan  53.4365   44.6132     65.46        56          46
# ..               ...      ...       ...       ...       ...         ...
# 556      Cerro Largo -28.1486  -54.7381     71.01        57           6
# 557            Abnub  27.2696   31.1511     86.22        32           0
# 558          Marabba  12.3500   32.1833     78.91        75          67
# 559  Plettenberg Bay -34.0527   23.3716     55.56        55           0
# 560          Cayenne   4.9333  -52.3333     86.04        70          20
#
#      Wind Speed Country                 Date
# 0          8.05      TO  2022-08-31 20:04:11
# 1         24.56      PF  2022-08-31 20:13:05
# 2          2.08      NZ  2022-08-31 20:13:52
# 3         13.13      US  2022-08-31 20:13:26
# 4          7.90      RU  2022-08-31 20:13:52
# ..          ...     ...                  ...
# 556        8.21      BR  2022-08-31 20:29:23
# 557       12.12      EG  2022-08-31 20:29:23
# 558        9.08      SD  2022-08-31 20:29:24
# 559        9.28      ZA  2022-08-31 20:29:24
# 560       10.36      GF  2022-08-31 20:24:39
#
# [561 rows x 9 columns]

# %%
# Create the output File (CSV)
output_data_file = "clean_cities.csv"
# Export the City_Data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_df.count()
# Out:
# City          561
# Lat           561
# Lng           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Wind Speed    561
# Country       561
# Date          561
# dtype: int64
